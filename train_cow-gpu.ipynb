# %% [markdown]
# # Mask R-CNN - Train on Shapes Dataset
#
#
# This notebook shows how to train Mask R-CNN on your own dataset. To keep things simple we use a synthetic dataset of shapes (squares, triangles, and circles) which enables fast training. You'd still need a GPU, though, because the network backbone is a Resnet101, which would be too slow to train on a CPU. On a GPU, you can start to get okay-ish results in a few minutes, and good results in less than an hour.
#
# The code of the *Shapes* dataset is included below. It generates images on the fly, so it doesn't require downloading any data. And it can generate images of any size, so we pick a small image size to train faster.

# %%
device = "CPU"

import os

#IF NOT USING GPU
if device == "CPU":
    os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

import sys
import random
import math
import re
import time
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt
import json
import tensorflow

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from PIL import Image, ImageDraw

# Root directory of the project
ROOT_DIR = os.path.abspath(".")
# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log

import importlib

importlib.reload(modellib)

import inspect

# %matplotlib inline 

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)
    
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"
    
import tensorflow as tf
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")

if device == "GPU":
    physical_devices = tf.config.experimental.list_physical_devices('GPU')
    assert len(physical_devices) > 0, "Not enough GPU hardware devices available"
    config = tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Please install GPU version of TF

# %% [markdown]
# ## Configurations

# %%
class CowConfig(Config):
    """Configuration for training on the toy shapes dataset.
    Derives from the base Config class and overrides values specific
    to the toy shapes dataset.
    """
    # Give the configuration a recognizable name
    NAME = "shapes"

    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 8

    # Number of classes (including background)
    NUM_CLASSES = 1 + 3  # background + 3 shapes
    # (COW, PIG, PLATE)

    # Use small images for faster training. Set the limits of the small side
    # the large side, and that determines the image shape.
    IMAGE_MIN_DIM = 128
    IMAGE_MAX_DIM = 128

    # Use smaller anchors because our image and objects are small
    RPN_ANCHOR_SCALES = (8, 16, 32, 64, 128)  # anchor side in pixels

    # Reduce training ROIs per image because the images are small and have
    # few objects. Aim to allow ROI sampling to pick 33% positive ROIs.
    TRAIN_ROIS_PER_IMAGE = 32

    # Use a small epoch since the data is simple
    STEPS_PER_EPOCH = 25

    # use small validation steps since the epoch is small
    VALIDATION_STEPS = 5
    
    USE_MINI_MASK = False
    
config = CowConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     8
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 8
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  128
# IMAGE_META_SIZE                16
# IMAGE_MIN_DIM                  128
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [128 128   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           shapes
# NUM_CLASSES                    4
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                25
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  False
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               5
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# ## Notebook Preferences

# %%
def get_ax(rows=1, cols=1, size=8):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Change the default size attribute to control the size
    of rendered images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %% [markdown]
# ## Dataset
#
# Create a synthetic dataset
#
# Extend the Dataset class and add a method to load the shapes dataset, `load_shapes()`, and override the following methods:
#
# * load_image()
# * load_mask()
# * image_reference()

# %%
class CowDataset(utils.Dataset):
    """Generates the shapes synthetic dataset. The dataset consists of simple
    shapes (triangles, squares, circles) placed randomly on a blank surface.
    The images are generated on the fly. No file access required.
    """
    
    data_path = "/home/nvinden/Work/Mask_RCNN/custom_data"

    def load_shapes(self, split = "train"):
        """Generate the requested number of synthetic images.
        count: number of images to generate.
        height, width: the size of the generated images.
        """
        
        assert split in ["train", "test", "val"]
        
        # Add classes
        self.add_class("shapes", 1, "cow")
        self.add_class("shapes", 2, "pig")
        self.add_class("shapes", 3, "plate")
        
        # Create file tuple with all of the files ordered alphabetically. We use this for file
        # indexes
        self.file_list = [f.replace(".json", "") for f in os.listdir(os.path.join(self.data_path, split)) if os.path.isfile(os.path.join(self.data_path, split, f)) and ".json" in f]
        self.file_list = tuple(self.file_list)

        # Add images
        # Generate random specifications of images (i.e. color and
        # list of shapes sizes and locations). This is more compact than
        # actual images. Images are generated on the fly in load_image().
        for img_id in self.file_list:
            json_path = os.path.join(self.data_path, split, img_id + ".json")
            
            with open(json_path) as user_file:
                json_data = json.load(user_file)
                
            # Get Height and Width of image.
            if os.path.isfile(os.path.join(self.data_path, split, img_id + ".jpg")):
                img_path = os.path.join(self.data_path, split, img_id + ".jpg")
                with Image.open(img_path) as im:
                    width, height = im.size
            elif os.path.isfile(os.path.join(self.data_path, split, img_id + ".JPG")):
                img_path = os.path.join(self.data_path, split, img_id + ".JPG")
                with Image.open(img_path) as im:
                    width, height = im.size
            
            self.add_image("shapes", image_id = img_id, json_path = json_path,
                           path = img_path, width = width, height = height, 
                           polygons = json_data['shapes'])

    def load_image(self, image_id):
        """Generate an image from the specs of the given image ID.
        Typically this function loads the image from a file, but
        in this case it generates the image on the fly from the
        specs in image_info.
        """
        info = self.image_info[image_id]
        img_path = info["path"]
        with Image.open(img_path) as img:
            image = np.array(img)

        return image

    def image_reference(self, image_id):
        """Return the shapes data of the image."""
        return self.image_info[image_id]["path"]
        """
        info = self.image_info[image_id]
        if info["source"] == "shapes":
            return info["shapes"]
        else:
            super(self.__class__).image_reference(self, image_id)
        """

    def load_mask(self, image_id):
        """Generate instance masks for shapes of the given image ID.
        """
        info = self.image_info[image_id]
        polygons = info["polygons"]
        
        count = len(polygons)
        
        mask_list = list()
        class_ids = list()
        
        for i, instance in enumerate(polygons):
            label = instance["label"]
            points = instance["points"]
            points = [tuple(point) for point in points]
            
            label_index = self.class_names.index(label)
            
            img = Image.new('L', (info['width'], info['height']), 0)
            ImageDraw.Draw(img).polygon(points, outline=1, fill=1)
            mask = np.array(img)
            
            # TODO: FIX THIS TO TURN (3, 200, 300) -> (200, 300, 3) for exmaple
            mask.astype(np.bool)
            
            mask_list.append(mask)
            class_ids.append(label_index)
        
        mask_list = np.array(mask_list).astype(np.bool)
        mask_list = np.transpose(mask_list, [1, 2, 0])
        class_ids = np.array(class_ids).astype(np.int32)
        
        return mask_list.astype(np.bool), class_ids.astype(np.int32)

# %%
# Training dataset
dataset_train = CowDataset()
dataset_train.load_shapes("train")
dataset_train.prepare()

# Validation dataset
dataset_val = CowDataset()
dataset_val.load_shapes("test")
dataset_val.prepare()

# %%
# Load and display random samples
image_ids = np.random.choice(dataset_train.image_ids, 4)
for image_id in image_ids:
    image = dataset_train.load_image(image_id)
    mask, class_ids = dataset_train.load_mask(image_id)
    print(mask.shape)
    print(image.shape)
    visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)
# Out:
# (3864, 5152, 2)
# (3864, 5152, 3)
# (3864, 5152, 2)
# (3864, 5152, 3)
# (3864, 5152, 2)
# (3864, 5152, 3)
# (3864, 5152, 2)
# (3864, 5152, 3)

# %% [markdown]
# ## Create Model

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)

# %%
# Which weights to start with?
init_with = "last"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last(), by_name=True)
# Out:
# Re-starting from epoch 141

# %% [markdown]
# ## Training
#
# Train in two stages:
# 1. Only the heads. Here we're freezing all the backbone layers and training only the randomly initialized layers (i.e. the ones that we didn't use pre-trained weights from MS COCO). To train only the head layers, pass `layers='heads'` to the `train()` function.
#
# 2. Fine-tune all layers. For this simple example it's not necessary, but we're including it to show the process. Simply pass `layers="all` to train all layers.

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=90, 
            layers='heads')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: /home/nvinden/Work/Mask_RCNN/logs/shapes20230213T2230/mask_rcnn_shapes_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# rpn_model              (Functional)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/90
# 25/25 [==============================] - 91s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 10.6955 - rpn_class_loss: 0.1341 - rpn_bbox_loss: 2.6528 - mrcnn_class_loss: 0.3912 - mrcnn_bbox_loss: 1.6827 - mrcnn_mask_loss: 0.4870 - val_loss: 13.8676 - val_rpn_class_loss: 0.0974 - val_rpn_bbox_loss: 4.8052 - val_mrcnn_class_loss: 0.0272 - val_mrcnn_bbox_loss: 1.5589 - val_mrcnn_mask_loss: 0.4450
# Epoch 2/90
# 25/25 [==============================] - 63s 3s/step - batch: 12.0000 - size: 8.0000 - loss:
- val_rpn_class_loss: 0.0118 - val_rpn_bbox_loss: 0.4574 - val_mrcnn_class_loss: 0.1627 - val_mrcnn_bbox_loss: 0.3004 - val_mrcnn_mask_loss: 0.2629
# Epoch 22/90
# 25/25 [==============================] - 12s 492ms/step - batch: 12.0000 - size: 8.0000 - loss: 1.2321 - rpn_class_loss: 0.0099 - rpn_bbox_loss: 0.1698 - mrcnn_class_loss: 0.0651 - mrcnn_bbox_loss: 0.1510 - mrcnn_mask_loss: 0.2202 - val_loss: 2.1425 - val_rpn_class_loss: 0.0143 - val_rpn_bbox_loss: 0.3992 - val_mrcnn_class_loss: 0.1117 - val_mrcnn_bbox_loss: 0.2901 - val_mrcnn_mask_loss: 0.2561
# Epoch 23/90
# 25/25 [==============================] - 50s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 1.1556 - rpn_class_loss: 0.0109 - rpn_bbox_loss: 0.1680 - mrcnn_class_loss: 0.0592 - mrcnn_bbox_loss: 0.1501 - mrcnn_mask_loss: 0.1897 - val_loss: 3.1973 - val_rpn_class_loss: 0.0219 - val_rpn_bbox_loss: 0.9273 - val_mrcnn_class_loss: 0.0572 - val_mrcnn_bbox_loss: 0.2958 - val_mrcnn_mask_loss: 0.2965
# Epoch 24/90
# 25/25 [==============================] - 47s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 1.4889 - rpn_class_loss: 0.0106 - rpn_bbox_loss: 0.2326 - mrcnn_class_loss: 0.0723 - mrcnn_bbox_loss: 0.1732 - mrcnn_mask_loss: 0.2557 - val_loss: 2.0348 - val_rpn_class_loss: 0.0109 - val_rpn_bbox_loss: 0.3938 - val_mrcnn_class_loss: 0.0560 - val_mrcnn_bbox_loss: 0.2709 - val_mrcnn_mask_loss: 0.2858
# Epoch 25/90
# 25/25 [==============================] - 48s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 1.1483 - rpn_class_loss: 0.0091 - rpn_bbox_loss: 0.1657 - mrcnn_class_loss: 0.0609 - mrcnn_bbox_loss: 0.1426 - mrcnn_mask_loss: 0.1959 - val_loss: 2.3991 - val_rpn_class_loss: 0.0275 - val_rpn_bbox_loss: 0.4902 - val_mrcnn_class_loss: 0.0808 - val_mrcnn_bbox_loss: 0.3323 - val_mrcnn_mask_loss: 0.2687
# Epoch 26/90
# 25/25 [==============================] - 50s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.9668 - rpn_class_loss: 0.0092 - rpn_bbox_loss: 0.1138 - mrcnn_class_loss: 0.0579 - mrcnn_bbox_loss: 0.1185 - mrcnn_mask_loss: 0.1840 - val_loss: 2.0702 - val_rpn_class_loss: 0.0126 - val_rpn_bbox_loss: 0.4173 - val_mrcnn_class_loss: 0.0855 - val_mrcnn_bbox_loss: 0.2846 - val_mrcnn_mask_loss: 0.2351
# Epoch 27/90
# 25/25 [==============================] - 49s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 1.1663 - rpn_class_loss: 0.0096 - rpn_bbox_loss: 0.1631 - mrcnn_class_loss: 0.0701 - mrcnn_bbox_loss: 0.1415 - mrcnn_mask_loss: 0.1989 - val_loss: 2.5621 - val_rpn_class_loss: 0.0129 - val_rpn_bbox_loss: 0.6272 - val_mrcnn_class_loss: 0.0533 - val_mrcnn_bbox_loss: 0.3112 - val_mrcnn_mask_loss: 0.2765
# Epoch 28/90
# 25/25 [==============================] - 53s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 1.2151 - rpn_class_loss: 0.0114 - rpn_bbox_loss: 0.1897 - mrcnn_class_loss: 0.0730 - mrcnn_bbox_loss: 0.1354 - mrcnn_mask_loss: 0.1980 - val_loss: 2.1118 - val_rpn_class_loss: 0.0152 - val_rpn_bbox_loss: 0.4794 - val_mrcnn_class_loss: 0.0683 - val_mrcnn_bbox_loss: 0.2437 - val_mrcnn_mask_loss: 0.2494
# Epoch 29/90
# 25/25 [==============================] - 48s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0
# 25/25 [==============================] - 52s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.7207 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.1035 - mrcnn_class_loss: 0.0375 - mrcnn_bbox_loss: 0.0747 - mrcnn_mask_loss: 0.1407 - val_loss: 1.7015 - val_rpn_class_loss: 0.0102 - val_rpn_bbox_loss: 0.3571 - val_mrcnn_class_loss: 0.0602 - val_mrcnn_bbox_loss: 0.2031 - val_mrcnn_mask_loss: 0.2201
# Epoch 46/90
# 25/25 [==============================] - 47s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.8298 - rpn_class_loss: 0.0062 - rpn_bbox_loss: 0.1184 - mrcnn_class_loss: 0.0448 - mrcnn_bbox_loss: 0.0964 - mrcnn_mask_loss: 0.1491 - val_loss: 1.8306 - val_rpn_class_loss: 0.0111 - val_rpn_bbox_loss: 0.4669 - val_mrcnn_class_loss: 0.0292 - val_mrcnn_bbox_loss: 0.2020 - val_mrcnn_mask_loss: 0.2061
# Epoch 47/90
# 25/25 [==============================] - 61s 3s/step - batch: 12.0000 - size: 8.0000 - loss: 0.8732 - rpn_class_loss: 0.0112 - rpn_bbox_loss: 0.1217 - mrcnn_class_loss: 0.0448 - mrcnn_bbox_loss: 0.0962 - mrcnn_mask_loss: 0.1626 - val_loss: 1.6736 - val_rpn_class_loss: 0.0115 - val_rpn_bbox_loss: 0.2970 - val_mrcnn_class_loss: 0.0769 - val_mrcnn_bbox_loss: 0.2178 - val_mrcnn_mask_loss: 0.2335
# Epoch 48/90
# 25/25 [==============================] - 55s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.7763 - rpn_class_loss: 0.0086 - rpn_bbox_loss: 0.0996 - mrcnn_class_loss: 0.0415 - mrcnn_bbox_loss: 0.0848 - mrcnn_mask_loss: 0.1536 - val_loss: 1.7498 - val_rpn_class_loss: 0.0109 - val_rpn_bbox_loss: 0.3842 - val_mrcnn_class_loss: 0.0699 - val_mrcnn_bbox_loss: 0.1866 - val_mrcnn_mask_loss: 0.2233
# Epoch 49/90
# 25/25 [==============================] - 50s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.8195 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.0957 - mrcnn_class_loss: 0.0521 - mrcnn_bbox_loss: 0.0932 - mrcnn_mask_loss: 0.1631 - val_loss: 1.6123 - val_rpn_class_loss: 0.0124 - val_rpn_bbox_loss: 0.3314 - val_mrcnn_class_loss: 0.0580 - val_mrcnn_bbox_loss: 0.1775 - val_mrcnn_mask_loss: 0.2269
# Epoch 50/90
# 25/25 [==============================] - 51s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.7623 - rpn_class_loss: 0.0071 - rpn_bbox_loss: 0.1065 - mrcnn_class_loss: 0.0399 - mrcnn_bbox_loss: 0.0751 - mrcnn_mask_loss: 0.1524 - val_loss: 1.5196 - val_rpn_class_loss: 0.0099 - val_rpn_bbox_loss: 0.2844 - val_mrcnn_class_loss: 0.0501 - val_mrcnn_bbox_loss: 0.1958 - val_mrcnn_mask_loss: 0.2196
# Epoch 51/90
# 25/25 [==============================] - 11s 462ms/step - batch: 12.0000 - size: 8.0000 - loss: 0.6911 - rpn_class_loss: 0.0085 - rpn_bbox_loss: 0.0910 - mrcnn_class_loss: 0.0397 - mrcnn_bbox_loss: 0.0614 - mrcnn_mask_loss: 0.1449 - val_loss: 1.4957 - val_rpn_class_loss: 0.0111 - val_rpn_bbox_loss: 0.3005 - val_mrcnn_class_loss: 0.0346 - val_mrcnn_bbox_loss: 0.1912 - val_mrcnn_mask_loss: 0.2103
# Epoch 52/90
# 25/25 [==============================] - 51s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.7081 - rpn_class_loss: 0.0101 - rpn_bbox_loss: 0.0792 - mrcnn_class_loss: 0.0454 - mrcnn_bbox_loss: 0.0722 - mrcnn_mask_loss: 0.1472 - val_loss: 1.6803 - val_rpn_class_loss: 0.0120 - val_rpn_bbox_loss: 0.3401 - val_mrcnn_class_loss: 0.0726 - val_mrcnn_bbox_loss: 0.1933 - val_mrcnn_mask_loss: 0.2223
# Epoch 53/90
# 25/25 [==============================] - 46s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.7301 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0
 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5189 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.0499 - mrcnn_class_loss: 0.0327 - mrcnn_bbox_loss: 0.0414 - mrcnn_mask_loss: 0.1314 - val_loss: 1.5289 - val_rpn_class_loss: 0.0149 - val_rpn_bbox_loss: 0.3278 - val_mrcnn_class_loss: 0.0288 - val_mrcnn_bbox_loss: 0.1665 - val_mrcnn_mask_loss: 0.2264
# Epoch 80/90
# 25/25 [==============================] - 12s 489ms/step - batch: 12.0000 - size: 8.0000 - loss: 0.4751 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.0376 - mrcnn_class_loss: 0.0293 - mrcnn_bbox_loss: 0.0391 - mrcnn_mask_loss: 0.1272 - val_loss: 1.2939 - val_rpn_class_loss: 0.0040 - val_rpn_bbox_loss: 0.2327 - val_mrcnn_class_loss: 0.0266 - val_mrcnn_bbox_loss: 0.1676 - val_mrcnn_mask_loss: 0.2160
# Epoch 81/90
# 25/25 [==============================] - 46s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5682 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.0445 - mrcnn_class_loss: 0.0443 - mrcnn_bbox_loss: 0.0495 - mrcnn_mask_loss: 0.1418 - val_loss: 1.4673 - val_rpn_class_loss: 0.0121 - val_rpn_bbox_loss: 0.3048 - val_mrcnn_class_loss: 0.0426 - val_mrcnn_bbox_loss: 0.1557 - val_mrcnn_mask_loss: 0.2184
# Epoch 82/90
# 25/25 [==============================] - 57s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5778 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.0696 - mrcnn_class_loss: 0.0348 - mrcnn_bbox_loss: 0.0522 - mrcnn_mask_loss: 0.1287 - val_loss: 1.5805 - val_rpn_class_loss: 0.0098 - val_rpn_bbox_loss: 0.3257 - val_mrcnn_class_loss: 0.0592 - val_mrcnn_bbox_loss: 0.1632 - val_mrcnn_mask_loss: 0.2324
# Epoch 83/90
# 25/25 [==============================] - 54s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5575 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.0629 - mrcnn_class_loss: 0.0299 - mrcnn_bbox_loss: 0.0483 - mrcnn_mask_loss: 0.1322 - val_loss: 1.2621 - val_rpn_class_loss: 0.0042 - val_rpn_bbox_loss: 0.2035 - val_mrcnn_class_loss: 0.0399 - val_mrcnn_bbox_loss: 0.1757 - val_mrcnn_mask_loss: 0.2077
# Epoch 84/90
# 25/25 [==============================] - 71s 3s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5298 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.0611 - mrcnn_class_loss: 0.0243 - mrcnn_bbox_loss: 0.0465 - mrcnn_mask_loss: 0.1288 - val_loss: 1.5662 - val_rpn_class_loss: 0.0094 - val_rpn_bbox_loss: 0.3865 - val_mrcnn_class_loss: 0.0269 - val_mrcnn_bbox_loss: 0.1762 - val_mrcnn_mask_loss: 0.1841
# Epoch 85/90
# 25/25 [==============================] - 52s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5347 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.0684 - mrcnn_class_loss: 0.0294 - mrcnn_bbox_loss: 0.0422 - mrcnn_mask_loss: 0.1228 - val_loss: 1.4614 - val_rpn_class_loss: 0.0136 - val_rpn_bbox_loss: 0.3041 - val_mrcnn_class_loss: 0.0347 - val_mrcnn_bbox_loss: 0.1532 - val_mrcnn_mask_loss: 0.2251os
# Epoch 86/90
# 25/25 [==============================] - 66s 3s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5729 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.0531 - mrcnn_class_loss: 0.0467 - mrcnn_bbox_loss: 0.0503 - mrcnn_mask_loss: 0.1314 - val_loss: 1.2181 - val_rpn_class_loss: 0.0055 - val_rpn_bbox_loss: 0.2105 - val_mrcnn_class_loss: 0.0593 - val_mrcnn_bbox_loss: 0.1394 - val_mrcnn_mask_loss: 0.1943
# Epoch 87/90
# 25/25 [==============================] - 48s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.4621 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.0265 - mrcnn_class_loss: 0.0359 - mrcnn_bbox_loss: 0.0373 - mrcnn_mask_loss: 0.1278 - val_loss: 1.2760 - val_rpn_class_loss: 0.0054 - val_rpn_bbox_loss: 0.2220 - val_mrcnn_class_loss: 0.0347 - val_mrcnn_bbox_loss: 0.1542 - val_mrcnn_mask_loss: 0.2218
# Epoch 88/90
# 25/25 [==============================] - 12s 480ms/step - batch: 12.0000 - size: 8.0000 - loss: 0.5895 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.0511 - mrcnn_class_loss: 0.0375 - mrcnn_bbox_loss: 0.0490 - mrcnn_mask_loss: 0.1520 - val_loss: 1.2942 - val_rpn_class_loss: 0.0084 - val_rpn_bbox_loss: 0.2363 - val_mrcnn_class_loss: 0.0440 - val_mrcnn_bbox_loss: 0.1621 - val_mrcnn_mask_loss: 0.1963
# Epoch 89/90
# 25/25 [==============================] - 46s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.4879 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.0341 - mrcnn_class_loss: 0.0306 - mrcnn_bbox_loss: 0.0475 - mrcnn_mask_loss: 0.1281 - val_loss: 1.3421 - val_rpn_class_loss: 0.0067 - val_rpn_bbox_loss: 0.2502 - val_mrcnn_class_loss: 0.0573 - val_mrcnn_bbox_loss: 0.1469 - val_mrcnn_mask_loss: 0.2100
# Epoch 90/90
# 25/25 [==============================] - 49s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5306 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0486 - mrcnn_class_loss: 0.0332 - mrcnn_bbox_loss: 0.0473 - mrcnn_mask_loss: 0.1330 - val_loss: 1.4686 - val_rpn_class_loss: 0.0102 - val_rpn_bbox_loss: 0.2731 - val_mrcnn_class_loss: 0.1006 - val_mrcnn_bbox_loss: 0.1388 - val_mrcnn_mask_loss: 0.2117

# %%
# Fine tune all layers
# Passing layers="all" trains all layers. You can also 
# pass a regular expression to select which layers to
# train by name pattern.
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE / 10,
            epochs=180, 
            layers="all")
# Out:
# Starting at epoch 90. LR=0.0001
#
# Checkpoint Path: /home/nvinden/Work/Mask_RCNN/logs/shapes20230213T2230/mask_rcnn_shapes_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res4g_branch2a         (Conv2D)
# bn4g_branch2a          (BatchNorm)
# res4g_branch2b         (Conv2D)
# bn4g_branch2b          (BatchNorm)
# res4g_branch2c         (Conv2D)
# bn4g_branch2c          (BatchNorm)
# res4h_branch2a         (Conv2D)
# bn4h_branch2a          (BatchNorm)
# res4h_branch2b         (Conv2D)
# bn4h_branch2b          (BatchNorm)
# res4h_branch2c         (Conv2D)
# bn4h_branch2c          (BatchNorm)
# res4i_branch2a         (Conv2D)
# bn4i_branch2a          (BatchNorm)
# res4i_branch2b         (Conv2D)
# bn4i_branch2b          (BatchNorm)
# res4i_branch2c         (Conv2D)
# bn4i_branch2c          (BatchNorm)
# res4j_branch2a         (Conv2D)
# bn4j_branch2a          (BatchNorm)
# res4j_branch2b         (Conv2D)
# bn4j_branch2b          (BatchNorm)
# res4j_branch2c         (Conv2D)
# bn4j_branch2c          (BatchNorm)
# res4k_branch2a         (Conv2D)
# bn4k_branch2a          (BatchNorm)
# res4k_branch2b         (Conv2D)
# bn4k_branch2b          (BatchNorm)
# res4k_branch2c         (Conv2D)
# bn4k_branch2c          (BatchNorm)
# res4l_branch2a         (Conv2D)
# bn4l_branch2a          (BatchNorm)
# res4l_branch2b         (Conv2D)
# bn4l_branch2b          (BatchNorm)
# res4l_branch2c         (Conv2D)
# bn4l_branch2c          (BatchNorm)
# res4m_branch2a         (Conv2D)
# bn4m_branch2a          (BatchNorm)
# res4m_branch2b         (Conv2D)
# bn4m_branch2b          (BatchNorm)
# res4m_branch2c         (Conv2D)
# bn4m_branch2c          (BatchNorm)
# res4n_branch2a         (Conv2D)
# bn4n_branch2a          (BatchNorm)
# res4n_branch2b         (Conv2D)
# bn4n_branch2b          (BatchNorm)
# res4n_branch2c         (Conv2D)
# bn4n_branch2c          (BatchNorm)
# res4o_branch2a         (Conv2D)
# bn4o_branch2a          (BatchNorm)
# res4o_branch2b         (Conv2D)
# bn4o_branch2b          (BatchNorm)
# res4o_branch2c         (Conv2D)
# bn4o_branch2c          (BatchNorm)
# res4p_branch2a         (Conv2D)
# bn4p_branch2a          (BatchNorm)
# res4p_branch2b         (Conv2D)
# bn4p_branch2b          (BatchNorm)
# res4p_branch2c         (Conv2D)
# bn4p_branch2c          (BatchNorm)
# res4q_branch2a         (Conv2D)
# bn4q_branch2a          (BatchNorm)
# res4q_branch2b         (Conv2D)
# bn4q_branch2b          (BatchNorm)
# res4q_branch2c         (Conv2D)
# bn4q_branch2c          (BatchNorm)
# res4r_branch2a         (Conv2D)
# bn4r_branch2a          (BatchNorm)
# res4r_branch2b         (Conv2D)
# bn4r_branch2b          (BatchNorm)
# res4r_branch2c         (Conv2D)
# bn4r_branch2c          (BatchNorm)
# res4s_branch2a         (Conv2D)
# bn4s_branch2a          (BatchNorm)
# res4s_branch2b         (Conv2D)
# bn4s_branch2b          (BatchNorm)
# res4s_branch2c         (Conv2D)
# bn4s_branch2c          (BatchNorm)
# res4t_branch2a         (Conv2D)
# bn4t_branch2a          (BatchNorm)
# res4t_branch2b         (Conv2D)
# bn4t_branch2b          (BatchNorm)
# res4t_branch2c         (Conv2D)
# bn4t_branch2c          (BatchNorm)
# res4u_branch2a         (Conv2D)
# bn4u_branch2a          (BatchNorm)
# res4u_branch2b         (Conv2D)
# bn4u_branch2b          (BatchNorm)
# res4u_branch2c         (Conv2D)
# bn4u_branch2c          (BatchNorm)
# res4v_branch2a         (Conv2D)
# bn4v_branch2a          (BatchNorm)
# res4v_branch2b         (Conv2D)
# bn4v_branch2b          (BatchNorm)
# res4v_branch2c         (Conv2D)
# bn4v_branch2c          (BatchNorm)
# res4w_branch2a         (Conv2D)
# bn4w_branch2a          (BatchNorm)
# res4w_branch2b         (Conv2D)
# bn4w_branch2b          (BatchNorm)
# res4w_branch2c         (Conv2D)
# bn4w_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# rpn_model              (Functional)
# anchors                (ConstLayer)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 91/180
# 25/25 [==============================] - 56s 669ms/step - batch: 12.0000 - size: 8.0000 - loss: 0.6634 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.0339 - mrcnn_class_loss: 0.0297 - mrcnn_bbox_loss: 0.0370 - mrcnn_mask_loss: 0.1163 - val_loss: 1.6942 - val_rpn_class_loss: 0.0084 - val_rpn_bbox_loss: 0.1658 - val_mrcnn_class_loss: 0.0455 - val_mrcnn_bbox_loss: 0.1490 - val_mrcnn_mask_loss: 0.1959
# Epoch 92/180
# 25/25 [==============================] - 57s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.7441 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.0329 - mrcnn_class_loss: 0.0372 - mrcnn_bbox_loss: 0.0477 - mrcnn_mask_loss: 0.1265 - val_loss: 2.2038 - val_rpn_class_loss: 0.0107 - val_rpn_bbox_loss: 0.2513 - val_mrcnn_class_loss: 0.0691 - val_mrcnn_bbox_loss: 0.1709 - val_mrcnn_mask_loss: 0.2325
# Epoch 93/180
# 25/25 [==============================] - 62s 3s/step - batch: 12.0000 - size: 8.0000 - loss: 0.7452 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.0417 - mrcnn_class_loss: 0.0327 - mrcnn_bbox_loss: 0.0442 - mrcnn_mask_loss: 0.1247 - val_loss: 2.1583 - val_rpn_class_loss: 0.0129 - val_rpn_bbox_loss: 0.3471 - val_mrcnn_class_loss: 0.0303 - val_mrcnn_bbox_loss: 0.1302 - val_mrcnn_mask_loss: 0.1989
# Epoch 94/180
# 25/25 [==============================] - 47s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.6744 - rpn_class_loss: 0.0041 - rpn_bbox_loss: 0.0261 - mrcnn_class_loss: 0.0284 - mrcnn_bbox_loss: 0.0387 - mrcnn_mask_loss: 0.1276 - val_loss: 1.6034 - val_rpn_class_loss: 0.0047 - val_rpn_bbox_loss: 0.1361 - val_mrcnn_class_loss: 0.0602 - val_mrcnn_bbox_loss: 0.1417 - val_mrcnn_mask_loss: 0.1917
# Epoch 95/180
# 25/25 [==============================] - 54s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.6903 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.0388 - mrcnn_class_loss: 0.0270 - mrcnn_bbox_loss: 0.0349 - mrcnn_mask_loss: 0.1251 - val_loss: 1.7545 - val_rpn_class_loss: 0.0082 - val_rpn_bbox_loss: 0.2096 - val_mrcnn_class_loss: 0.0503 - val_mrcnn_bbox_loss: 0.1227 - val_mrcnn_mask_loss: 0.1941
# Epoch 96/180
# 25/25 [==============================] - 62s 3s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5822 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.0292 - mrcnn_class_loss: 0.0161 - mrcnn_bbox_loss: 0.0294 - mrcnn_mask_loss: 0.1156 - val_loss: 1.9182 - val_rpn_class_loss: 0.0084 - val_rpn_bbox_loss: 0.1948 - val_mrcnn_class_loss: 0.0595 - val_mrcnn_bbox_loss: 0.1370 - val_mrcnn_mask_loss: 0.2396
# Epoch 97/180
# 25/25 [==============================] - 50s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5779 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.0275 - mrcnn_class_loss: 0.0216 - mrcnn_bbox_loss: 0.0292 - mrcnn_mask_loss: 0.1099 - val_loss: 1.7647 - val_rpn_class_loss: 0.0072 - val_rpn_bbox_loss: 0.1946 - val_mrcnn_class_loss: 0.0549 - val_mrcnn_bbox_loss: 0.1374 - val_mrcnn_mask_loss: 0.1942
# Epoch 98/180
# 25/25 [==============================] - 12s 508ms/step - batch: 12.0000 - size: 8.0000 - loss: 0.6235 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.0246 - mrcnn_class_loss: 0.0295 - mrcnn_bbox_loss: 0.0307 - mrcnn_mask_loss: 0.1202 - val_loss: 2.0107 - val_rpn_class_loss: 0.0088 - val_rpn_bbox_loss: 0.2360 - val_mrcnn_class_loss: 0.0478 - val_mrcnn_bbox_loss: 0.1344 - val_mrcnn_mask_loss: 0.2432
# Epoch 99/180
# 25/25 [==============================] - 58s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5792 - rpn_class_loss: 0.0033 - rpn_bbox_loss: 0.0211 - mrcnn_class_loss: 0.0241 - mrcnn_bbox_loss: 0.0277 - mrcnn_mask_loss: 0.1169 - val_loss: 1.8266 - val_rpn_class_loss: 0.0081 - val_rpn_bbox_loss: 0.2067 - val_mrcnn_class_loss: 0.0471 - val_mrcnn_bbox_loss: 0.1334 - val_mrcnn_mask_loss: 0.2136
# Epoch 100/180
# 25/25 [==============================] - 48s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.6122 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.0259 - mrcnn_class_loss: 0.0227 - mrcnn_bbox_loss: 0.0337 - mrcnn_mask_loss: 0.1192 - val_loss: 1.8120 - val_rpn_class_loss: 0.0064 - val_rpn_bbox_loss: 0.2432 - val_mrcnn_class_loss: 0.0394 - val_mrcnn_bbox_loss: 0.1124 - val_mrcnn_mask_loss: 0.2026
# Epoch 101/180
# 25/25 [==============================] - 47s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.6251 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.0298 - mrcnn_class_loss: 0.0204 - mrcnn_bbox_loss: 0.0311 - mrcnn_mask_loss: 0.1241 - val_loss: 1.9308 - val_rpn_class_loss: 0.0082 - val_rpn_bbox_loss: 0.2251 - val_mrcnn_class_loss: 0.0525 - val_mrcnn_bbox_loss: 0.1296 - val_mrcnn_mask_loss: 0.2282
# Epoch 102/180
# 25/25 [==============================] - 52s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.6712 - rpn_class_loss: 0.0040 - rpn_bbox_loss: 0.0307 - mrcnn_class_loss: 0.0322 - mrcnn_bbox_loss: 0.0384 - mrcnn_mask_loss: 0.1184 - val_loss: 1.6868 - val_rpn_class_loss: 0.0056 - val_rpn_bbox_loss: 0.1804 - val_mrcnn_class_loss: 0.0221 - val_mrcnn_bbox_loss: 0.1368 - val_mrcnn_mask_loss: 0.2173
# Epoch 103/180
# 25/25 [==============================] - 49s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5729 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.0265 - mrcnn_class_loss: 0.0206 - mrcnn_bbox_loss: 0.0297 - mrcnn_mask_loss: 0.1102 - val_loss: 1.8240 - val_rpn_class_loss: 0.0038 - val_rpn_bbox_loss: 0.2003 - val_mrcnn_class_loss: 0.0416 - val_mrcnn_bbox_loss: 0.1484 - val_mrcnn_mask_loss: 0.2138
# Epoch 104/180
# 25/25 [==============================] - 60s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5581 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0220 - mrcnn_class_loss: 0.0233 - mrcnn_bbox_loss: 0.0255 - mrcnn_mask_loss: 0.1125 - val_loss: 1.6890 - val_rpn_class_loss: 0.0060 - val_rpn_bbox_loss: 0.1878 - val_mrcnn_class_loss: 0.0420 - val_mrcnn_bbox_loss: 0.1219 - val_mrcnn_mask_loss: 0.2053
# Epoch 105/180
# 25/25 [==============================] - 13s 516ms/step - batch: 12.0000 - size: 8.0000 - loss: 0.5292 - rpn_class_loss: 0.0023 - rpn_bbox_loss: 0.0193 - mrcnn_class_loss: 0.0241 - mrcnn_bbox_loss: 0.0270 - mrcnn_mask_loss: 0.1037 - val_loss: 1.8880 - val_rpn_class_loss: 0.0102 - val_rpn_bbox_loss: 0.2428 - val_mrcnn_class_loss: 0.0316 - val_mrcnn_bbox_loss: 0.1154 - val_mrcnn_mask_loss: 0.2294
# Epoch 106/180
# 25/25 [==============================] - 57s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5999 - rpn_class_loss: 0.0037 - rpn_bbox_loss: 0.0228 - mrcnn_class_loss: 0.0305 - mrcnn_bbox_loss: 0.0271 - mrcnn_mask_loss: 0.1158 - val_loss: 1.7676 - val_rpn_class_loss: 0.0049 - val_rpn_bbox_loss: 0.1634 - val_mrcnn_class_loss: 0.0723 - val_mrcnn_bbox_loss: 0.1565 - val_mrcnn_mask_loss: 0.1921
# Epoch 107/180
# 25/25 [==============================] - 47s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.6345 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.0247 - mrcnn_class_loss: 0.0350 - mrcnn_bbox_loss: 0.0313 - mrcnn_mask_loss: 0.1179 - val_loss: 1.8165 - val_rpn_class_loss: 0.0074 - val_rpn_bbox_loss: 0.1876 - val_mrcnn_class_loss: 0.0547 - val_mrcnn_bbox_loss: 0.1322 - val_mrcnn_mask_loss: 0.2236
# Epoch 108/180
# 25/25 [==============================] - 47s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.6027 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.0243 - mrcnn_class_loss: 0.0240 - mrcnn_bbox_loss: 0.0313 - mrcnn_mask_loss: 0.1180 - val_loss: 1.7310 - val_rpn_class_loss: 0.0073 - val_rpn_bbox_loss: 0.2123 - val_mrcnn_class_loss: 0.0405 - val_mrcnn_bbox_loss: 0.1224 - val_mrcnn_mask_loss: 0.1946
# Epoch 109/180
# 25/25 [==============================] - 50s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5991 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.0253 - mrcnn_class_loss: 0.0254 - mrcnn_bbox_loss: 0.0302 - mrcnn_mask_loss: 0.1152 - val_loss: 1.6263 - val_rpn_class_loss: 0.0078 - val_rpn_bbox_loss: 0.1722 - val_mrcnn_class_loss: 0.0428 - val_mrcnn_bbox_loss: 0.1426 - val_mrcnn_mask_loss: 0.1767
# Epoch 110/180
# 25/25 [==============================] - 52s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.6428 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.0267 - mrcnn_class_loss: 0.0276 - mrcnn_bbox_loss: 0.0333 - mrcnn_mask_loss: 0.1232 - val_loss: 1.6645 - val_rpn_class_loss: 0.0091 - val_rpn_bbox_loss: 0.1765 - val_mrcnn_class_loss: 0.0605 - val_mrcnn_bbox_loss: 0.1190 - val_mrcnn_mask_loss: 0.1897
# Epoch 111/180
# 25/25 [==============================] - 71s 3s/step - batch: 12.0000 - size: 8.0000 - loss: 0.6157 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0249 - mrcnn_class_loss: 0.0207 - mrcnn_bbox_loss: 0.0300 - mrcnn_mask_loss: 0.1268 - val_loss: 1.7118 - val_rpn_class_loss: 0.0067 - val_rpn_bbox_loss: 0.1863 - val_mrcnn_class_loss: 0.0547 - val_mrcnn_bbox_loss: 0.1182 - val_mrcnn_mask_loss: 0.2046
# Epoch 112/180
# 25/25 [==============================] - 13s 551ms/step - batch: 12.0000 - size: 8.0000 - loss: 0.6266 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0239 - mrcnn_class_loss: 0.0254 - mrcnn_bbox_loss: 0.0314 - mrcnn_mask_loss: 0.1257 - val_loss: 1.8039 - val_rpn_class_loss: 0.0060 - val_rpn_bbox_loss: 0.2165 - val_mrcnn_class_loss: 0.0375 - val_mrcnn_bbox_loss: 0.1102 - val_mrcnn_mask_loss: 0.2311
# Epoch 113/180
# 25/25 [==============================] - 64s 3s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5518 - rpn_class_loss: 0.0033 - rpn_bbox_loss: 0.0209 - mrcnn_class_loss: 0.0209 - mrcnn_bbox_loss: 0.0273 - mrcnn_mask_loss: 0.1114 - val_loss: 1.7345 - val_rpn_class_loss: 0.0057 - val_rpn_bbox_loss: 0.2233 - val_mrcnn_class_loss: 0.0244 - val_mrcnn_bbox_loss: 0.1328 - val_mrcnn_mask_loss: 0.1918
# Epoch 114/180
# 25/25 [==============================] - 44s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.6133 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.0267 - mrcnn_class_loss: 0.0234 - mrcnn_bbox_loss: 0.0315 - mrcnn_mask_loss: 0.1190 - val_loss: 1.7252 - val_rpn_class_loss: 0.0039 - val_rpn_bbox_loss: 0.1996 - val_mrcnn_class_loss: 0.0386 - val_mrcnn_bbox_loss: 0.1319 - val_mrcnn_mask_loss: 0.2011
# Epoch 115/180
# 25/25 [==============================] - 52s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5695 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.0265 - mrcnn_class_loss: 0.0238 - mrcnn_bbox_loss: 0.0275 - mrcnn_mask_loss: 0.1092 - val_loss: 1.6302 - val_rpn_class_loss: 0.0056 - val_rpn_bbox_loss: 0.1921 - val_mrcnn_class_loss: 0.0504 - val_mrcnn_bbox_loss: 0.1228 - val_mrcnn_mask_loss: 0.1724
# Epoch 116/180
# 25/25 [==============================] - 48s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5787 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.0255 - mrcnn_class_loss: 0.0260 - mrcnn_bbox_loss: 0.0275 - mrcnn_mask_loss: 0.1113 - val_loss: 1.7112 - val_rpn_class_loss: 0.0049 - val_rpn_bbox_loss: 0.1755 - val_mrcnn_class_loss: 0.0639 - val_mrcnn_bbox_loss: 0.1339 - val_mrcnn_mask_loss: 0.1921
# Epoch 117/180
# 25/25 [==============================] - 58s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5679 - rpn_class_loss: 0.0020 - rpn_bbox_loss: 0.0214 - mrcnn_class_loss: 0.0301 - mrcnn_bbox_loss: 0.0247 - mrcnn_mask_loss: 0.1111 - val_loss: 1.7573 - val_rpn_class_loss: 0.0081 - val_rpn_bbox_loss: 0.2145 - val_mrcnn_class_loss: 0.0424 - val_mrcnn_bbox_loss: 0.1215 - val_mrcnn_mask_loss: 0.1992
# Epoch 118/180
# 25/25 [==============================] - 56s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5156 - rpn_class_loss: 0.0021 - rpn_bbox_loss: 0.0159 - mrcnn_class_loss: 0.0213 - mrcnn_bbox_loss: 0.0221 - mrcnn_mask_loss: 0.1104 - val_loss: 1.8743 - val_rpn_class_loss: 0.0091 - val_rpn_bbox_loss: 0.2544 - val_mrcnn_class_loss: 0.0223 - val_mrcnn_bbox_loss: 0.1191 - val_mrcnn_mask_loss: 0.2199
# Epoch 119/180
# 25/25 [==============================] - 51s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5038 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.0152 - mrcnn_class_loss: 0.0211 - mrcnn_bbox_loss: 0.0214 - mrcnn_mask_loss: 0.1070 - val_loss: 1.8145 - val_rpn_class_loss: 0.0061 - val_rpn_bbox_loss: 0.2241 - val_mrcnn_class_loss: 0.0396 - val_mrcnn_bbox_loss: 0.1339 - val_mrcnn_mask_loss: 0.2011
# Epoch 120/180
# 25/25 [==============================] - 13s 533ms/step - batch: 12.0000 - size: 8.0000 - loss: 0.6420 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.0220 - mrcnn_class_loss: 0.0310 - mrcnn_bbox_loss: 0.0349 - mrcnn_mask_loss: 0.1231 - val_loss: 1.8266 - val_rpn_class_loss: 0.0068 - val_rpn_bbox_loss: 0.2486 - val_mrcnn_class_loss: 0.0429 - val_mrcnn_bbox_loss: 0.1190 - val_mrcnn_mask_loss: 0.1917
# Epoch 121/180
# 25/25 [==============================] - 55s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5141 - rpn_class_loss: 0.0041 - rpn_bbox_loss: 0.0188 - mrcnn_class_loss: 0.0162 - mrcnn_bbox_loss: 0.0224 - mrcnn_mask_loss: 0.1098 - val_loss: 1.6529 - val_rpn_class_loss: 0.0047 - val_rpn_bbox_loss: 0.1994 - val_mrcnn_class_loss: 0.0404 - val_mrcnn_bbox_loss: 0.1049 - val_mrcnn_mask_loss: 0.2017
# Epoch 122/180
# 25/25 [==============================] - 48s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5993 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.0236 - mrcnn_class_loss: 0.0227 - mrcnn_bbox_loss: 0.0309 - mrcnn_mask_loss: 0.1198 - val_loss: 2.0081 - val_rpn_class_loss: 0.0105 - val_rpn_bbox_loss: 0.3294 - val_mrcnn_class_loss: 0.0391 - val_mrcnn_bbox_loss: 0.1169 - val_mrcnn_mask_loss: 0.1735
# Epoch 123/180
# 25/25 [==============================] - 56s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.6209 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0273 - mrcnn_class_loss: 0.0252 - mrcnn_bbox_loss: 0.0281 - mrcnn_mask_loss: 0.1238 - val_loss: 1.7016 - val_rpn_class_loss: 0.0066 - val_rpn_bbox_loss: 0.1876 - val_mrcnn_class_loss: 0.0302 - val_mrcnn_bbox_loss: 0.1355 - val_mrcnn_mask_loss: 0.2073
# Epoch 124/180
# 25/25 [==============================] - 61s 3s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5855 - rpn_class_loss: 0.0023 - rpn_bbox_loss: 0.0218 - mrcnn_class_loss: 0.0269 - mrcnn_bbox_loss: 0.0259 - mrcnn_mask_loss: 0.1182 - val_loss: 1.6763 - val_rpn_class_loss: 0.0057 - val_rpn_bbox_loss: 0.1932 - val_mrcnn_class_loss: 0.0366 - val_mrcnn_bbox_loss: 0.1160 - val_mrcnn_mask_loss: 0.2073
# Epoch 125/180
# 25/25 [==============================] - 67s 3s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5336 - rpn_class_loss: 0.0022 - rpn_bbox_loss: 0.0179 - mrcnn_class_loss: 0.0290 - mrcnn_bbox_loss: 0.0220 - mrcnn_mask_loss: 0.1067 - val_loss: 1.8658 - val_rpn_class_loss: 0.0087 - val_rpn_bbox_loss: 0.2490 - val_mrcnn_class_loss: 0.0465 - val_mrcnn_bbox_loss: 0.1265 - val_mrcnn_mask_loss: 0.1913
# Epoch 126/180
# 25/25 [==============================] - 87s 4s/step - batch: 12.0000 - size: 8.0000 - loss: 0.4920 - rpn_class_loss: 0.0020 - rpn_bbox_loss: 0.0161 - mrcnn_class_loss: 0.0160 - mrcnn_bbox_loss: 0.0224 - mrcnn_mask_loss: 0.1075 - val_loss: 1.6687 - val_rpn_class_loss: 0.0059 - val_rpn_bbox_loss: 0.1684 - val_mrcnn_class_loss: 0.0562 - val_mrcnn_bbox_loss: 0.1359 - val_mrcnn_mask_loss: 0.1898
# Epoch 127/180
# 25/25 [==============================] - 13s 535ms/step - batch: 12.0000 - size: 8.0000 - loss: 0.4977 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0156 - mrcnn_class_loss: 0.0214 - mrcnn_bbox_loss: 0.0210 - mrcnn_mask_loss: 0.1054 - val_loss: 1.7801 - val_rpn_class_loss: 0.0074 - val_rpn_bbox_loss: 0.2190 - val_mrcnn_class_loss: 0.0308 - val_mrcnn_bbox_loss: 0.1103 - val_mrcnn_mask_loss: 0.2259
# Epoch 128/180
# 25/25 [==============================] - 46s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.4857 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0146 - mrcnn_class_loss: 0.0168 - mrcnn_bbox_loss: 0.0185 - mrcnn_mask_loss: 0.1095 - val_loss: 1.7019 - val_rpn_class_loss: 0.0076 - val_rpn_bbox_loss: 0.2064 - val_mrcnn_class_loss: 0.0332 - val_mrcnn_bbox_loss: 0.1168 - val_mrcnn_mask_loss: 0.2033
# Epoch 129/180
# 25/25 [==============================] - 61s 3s/step - batch: 12.0000 - size: 8.0000 - loss: 0.4948 - rpn_class_loss: 0.0023 - rpn_bbox_loss: 0.0168 - mrcnn_class_loss: 0.0165 - mrcnn_bbox_loss: 0.0219 - mrcnn_mask_loss: 0.1074 - val_loss: 1.8949 - val_rpn_class_loss: 0.0069 - val_rpn_bbox_loss: 0.2367 - val_mrcnn_class_loss: 0.0456 - val_mrcnn_bbox_loss: 0.1216 - val_mrcnn_mask_loss: 0.2208
# Epoch 130/180
# 25/25 [==============================] - 55s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5508 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0171 - mrcnn_class_loss: 0.0264 - mrcnn_bbox_loss: 0.0250 - mrcnn_mask_loss: 0.1122 - val_loss: 2.0367 - val_rpn_class_loss: 0.0090 - val_rpn_bbox_loss: 0.2868 - val_mrcnn_class_loss: 0.0655 - val_mrcnn_bbox_loss: 0.1060 - val_mrcnn_mask_loss: 0.2115
# Epoch 131/180
# 25/25 [==============================] - 52s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.6318 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.0222 - mrcnn_class_loss: 0.0256 - mrcnn_bbox_loss: 0.0340 - mrcnn_mask_loss: 0.1246 - val_loss: 1.3513 - val_rpn_class_loss: 0.0031 - val_rpn_bbox_loss: 0.1418 - val_mrcnn_class_loss: 0.0197 - val_mrcnn_bbox_loss: 0.1189 - val_mrcnn_mask_loss: 0.1669
# Epoch 132/180
# 25/25 [==============================] - 49s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5740 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.0192 - mrcnn_class_loss: 0.0253 - mrcnn_bbox_loss: 0.0266 - mrcnn_mask_loss: 0.1158 - val_loss: 1.6239 - val_rpn_class_loss: 0.0060 - val_rpn_bbox_loss: 0.1537 - val_mrcnn_class_loss: 0.0476 - val_mrcnn_bbox_loss: 0.1342 - val_mrcnn_mask_loss: 0.1998
# Epoch 133/180
# 25/25 [==============================] - 47s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5570 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.0178 - mrcnn_class_loss: 0.0269 - mrcnn_bbox_loss: 0.0252 - mrcnn_mask_loss: 0.1115 - val_loss: 1.7450 - val_rpn_class_loss: 0.0069 - val_rpn_bbox_loss: 0.2319 - val_mrcnn_class_loss: 0.0301 - val_mrcnn_bbox_loss: 0.1055 - val_mrcnn_mask_loss: 0.2073
# Epoch 134/180
# 25/25 [==============================] - 12s 495ms/step - batch: 12.0000 - size: 8.0000 - loss: 0.5523 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.0196 - mrcnn_class_loss: 0.0217 - mrcnn_bbox_loss: 0.0246 - mrcnn_mask_loss: 0.1126 - val_loss: 1.9219 - val_rpn_class_loss: 0.0083 - val_rpn_bbox_loss: 0.2327 - val_mrcnn_class_loss: 0.0322 - val_mrcnn_bbox_loss: 0.1332 - val_mrcnn_mask_loss: 0.2343
# Epoch 135/180
# 25/25 [==============================] - 49s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5314 - rpn_class_loss: 0.0035 - rpn_bbox_loss: 0.0179 - mrcnn_class_loss: 0.0219 - mrcnn_bbox_loss: 0.0239 - mrcnn_mask_loss: 0.1099 - val_loss: 1.7318 - val_rpn_class_loss: 0.0072 - val_rpn_bbox_loss: 0.1953 - val_mrcnn_class_loss: 0.0373 - val_mrcnn_bbox_loss: 0.1183 - val_mrcnn_mask_loss: 0.2192
# Epoch 136/180
# 25/25 [==============================] - 57s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5208 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0166 - mrcnn_class_loss: 0.0154 - mrcnn_bbox_loss: 0.0228 - mrcnn_mask_loss: 0.1156 - val_loss: 1.7096 - val_rpn_class_loss: 0.0069 - val_rpn_bbox_loss: 0.2323 - val_mrcnn_class_loss: 0.0252 - val_mrcnn_bbox_loss: 0.1203 - val_mrcnn_mask_loss: 0.1851
# Epoch 137/180
# 25/25 [==============================] - 50s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5227 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.0180 - mrcnn_class_loss: 0.0219 - mrcnn_bbox_loss: 0.0201 - mrcnn_mask_loss: 0.1098 - val_loss: 1.7546 - val_rpn_class_loss: 0.0063 - val_rpn_bbox_loss: 0.2352 - val_mrcnn_class_loss: 0.0232 - val_mrcnn_bbox_loss: 0.1147 - val_mrcnn_mask_loss: 0.2056
# Epoch 138/180
# 25/25 [==============================] - 50s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5430 - rpn_class_loss: 0.0033 - rpn_bbox_loss: 0.0140 - mrcnn_class_loss: 0.0247 - mrcnn_bbox_loss: 0.0210 - mrcnn_mask_loss: 0.1180 - val_loss: 1.6681 - val_rpn_class_loss: 0.0052 - val_rpn_bbox_loss: 0.1947 - val_mrcnn_class_loss: 0.0364 - val_mrcnn_bbox_loss: 0.1275 - val_mrcnn_mask_loss: 0.1922
# Epoch 139/180
# 25/25 [==============================] - 50s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.5291 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.0184 - mrcnn_class_loss: 0.0228 - mrcnn_bbox_loss: 0.0210 - mrcnn_mask_loss: 0.1110 - val_loss: 1.4306 - val_rpn_class_loss: 0.0055 - val_rpn_bbox_loss: 0.1689 - val_mrcnn_class_loss: 0.0431 - val_mrcnn_bbox_loss: 0.1007 - val_mrcnn_mask_loss: 0.1588
# Epoch 140/180
# 25/25 [==============================] - 45s 2s/step - batch: 12.0000 - size: 8.0000 - loss: 0.4999 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.0170 - mrcnn_class_loss: 0.0203 - mrcnn_bbox_loss: 0.0204 - mrcnn_mask_loss: 0.1051 - val_loss: 1.6188 - val_rpn_class_loss: 0.0049 - val_rpn_bbox_loss: 0.2070 - val_mrcnn_class_loss: 0.0241 - val_mrcnn_bbox_loss: 0.1152 - val_mrcnn_mask_loss: 0.1885
# Epoch 141/180
# 25/25 [==============================] - 13s 521ms/step - batch: 12.0000 - size: 8.0000 - loss: 0.4917 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.0151 - mrcnn_class_loss: 0.0181 - mrcnn_bbox_loss: 0.0175 - mrcnn_mask_loss: 0.1100 - val_loss: 1.7487 - val_rpn_class_loss: 0.0050 - val_rpn_bbox_loss: 0.2323 - val_mrcnn_class_loss: 0.0421 - val_mrcnn_bbox_loss: 0.1139 - val_mrcnn_mask_loss: 0.1896
# Epoch 142/180
#  1/25 [>.............................] - ETA: 6s - batch: 0.0000e+00 - size: 8.0000 - loss: 0.4940 - rpn_class_loss: 0.0014 - rpn_bbox_loss: 0.0164 - mrcnn_class_loss: 0.0228 - mrcnn_bbox_loss: 0.0187 - mrcnn_mask_loss: 0.1054

# %%
# Save weights
# Typically not needed because callbacks save after every epoch
# Uncomment to save manually
model_path = os.path.join(MODEL_DIR, "mask_rcnn_cow5.h5")
model.keras_model.save_weights(model_path)

# %% [markdown]
# ## Detection

# %%
class InferenceConfig(CowConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1


inference_config = InferenceConfig()

from keras.backend import manual_variable_initialization 
manual_variable_initialization(True)

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=MODEL_DIR)

# Get path to saved weights
# Either set a specific path or find last trained weights
# model_path = os.path.join(ROOT_DIR, ".h5 file name here")

#model_path = model.find_last()
model_path = "/home/nvinden/Work/Mask_RCNN/logs/shapes20230213T2230/mask_rcnn_shapes_0141.h5"

# Load trained weights
print("Loading weights from ", model_path)
#model.load_weights(model_path, by_name=True)

import tensorflow.compat.v1 as tf

tf.keras.Model.load_weights(model.keras_model, model_path, by_name=True)
# Out:
# WARNING:tensorflow:From /home/nvinden/anaconda3/envs/tf3/lib/python3.6/site-packages/tensorflow/python/util/deprecation.py:617: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# Loading weights from  /home/nvinden/Work/Mask_RCNN/logs/shapes20230213T2230/mask_rcnn_shapes_0141.h5

# %%
# Test on a random image
image_id = random.choice(dataset_val.image_ids)
original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
    modellib.load_image_gt(dataset_val, inference_config, 
                           image_id)

log("original_image", original_image)
log("image_meta", image_meta)
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)

visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                            dataset_train.class_names, figsize=(8, 8))
# Out:
# original_image           shape: (128, 128, 3)         min:    0.00000  max:  255.00000  uint8
# image_meta               shape: (16,)                 min:    0.00000  max: 5152.00000  float64
# gt_class_id              shape: (2,)                  min:    1.00000  max:    3.00000  int32
# gt_bbox                  shape: (2, 4)                min:   13.00000  max:  109.00000  int32
# gt_mask                  shape: (128, 128, 2)         min:    0.00000  max:    1.00000  bool

# %%
import time
start_time = time.time()
results = model.detect([original_image], verbose=1)
print("--- %s seconds ---" % (time.time() - start_time))

r = results[0]
visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                            dataset_val.class_names, r['scores'], ax=get_ax())
# Out:
# Processing 1 images
# image                    shape: (128, 128, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 128, 128, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 16)               min:    0.00000  max:  128.00000  int64
# anchors                  shape: (1, 4092, 4)          min:   -0.71267  max:    1.20874  float32
# --- 0.25898003578186035 seconds ---

# %% [markdown]
# ## Evaluation

# %%
# Compute VOC-Style mAP @ IoU=0.5
# Running on 10 images. Increase for better accuracy.
image_ids = np.random.choice(dataset_val.image_ids, 10)
APs = []
for image_id in image_ids:
    # Load image and ground truth data
    image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config,
                               image_id)
    molded_images = np.expand_dims(modellib.mold_image(image, inference_config), 0)
    # Run object detection
    results = model.detect([image], verbose=0)
    r = results[0]
    # Compute AP
    AP, precisions, recalls, overlaps =\
        utils.compute_ap(gt_bbox, gt_class_id, gt_mask,
                         r["rois"], r["class_ids"], r["scores"], r['masks'])
    APs.append(AP)
    
print("mAP: ", np.mean(APs))
# Out:
# mAP:  1.0
